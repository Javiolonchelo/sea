# %% [markdown]
# # Filtros de cruce

# %%
import numpy as np
from sympy.abc import s
from sympy.physics.control.lti import TransferFunction
from sympy.physics.control.control_plots import bode_plot
import math

def my_bode_plot(tf, normalized=True):
    if normalized:
        bode_plot(tf, initial_exp=-2, final_exp=2, freq_unit='Hz', show_axes=True)
    else:
        bode_plot(tf, initial_exp=1, final_exp=5, freq_unit='Hz', show_axes=True)


# Def the transfer function as a symbolic expression
w = np.logspace(2*math.pi*20, 2*math.pi*20000, 1000)
wl = 2*math.pi * 400
Hl = 1 / (s + 1)**2
Hh = - s**2 / ((s + 1)**2)
# Hl = Hl.subs(s, s/wl)
# Hh = Hh.subs(s, s/wl)
num_Hl, den_Hl = Hl.as_numer_denom()
num_Hh, den_Hh = Hh.as_numer_denom()

tf_Hl = TransferFunction(num_Hl, den_Hl, s)
tf_Hh = TransferFunction(num_Hh, den_Hh, s)

display(num_Hl/den_Hl, num_Hh/den_Hh)

# Bode plot


my_bode_plot(tf_Hl)
my_bode_plot(tf_Hh)
# Out:
# /home/javi/Documentos/github/sea/.venv/lib/python3.10/site-packages/numpy/_core/function_base.py:314: RuntimeWarning: overflow encountered in power
#   return _nx.power(base, y)
# (s + 1)**(-2)
# -s**2/(s + 1)**2

# %%
H_total = num_Hl/den_Hl + num_Hh/den_Hh


display("H total", H_total)
H_total = H_total.subs(s, s/wl)
display("H total at wl", H_total)

# get num and den
num, den = H_total.as_numer_denom()
display(num, den)
tf_total = TransferFunction(num, den, s)
my_bode_plot(tf_total)
# Out:
# 'H total'
# -s**2/(s + 1)**2 + (s + 1)**(-2)
# 'H total at wl'
# -1.58314349441153e-7*s**2/(0.000397887357729738*s + 1)**2 + (0.000397887357729738*s + 1)**(-2)
# 1 - 1.58314349441153e-7*s**2
# (0.000397887357729738*s + 1)**2
